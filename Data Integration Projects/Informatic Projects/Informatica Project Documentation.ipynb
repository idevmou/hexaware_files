# %% [markdown]
# # Data Integration for E-commerce Website - Informatica[ETL]
# <hr>

# %% [markdown]
# This project was done by using the Informatica PowerCenter V10.4.1
#
# ![image.png](attachment:image.png)

# %% [markdown]
# * Here I performed various data source that are collected and tranformed into a Data Warehouse.
# * Data Warehouse : SQL SERVER 2022
# * Project Platform [ETL Tool] : Informatica PowerCenter
# * Data : All datas are open source and generated by Mockaroo.

# %% [markdown]
# ### Requirements and dataset structure details:

# %% [markdown]
# 1. **Data Sources**: The company has the following data sources that need to be integrated into the data warehouse:
# 2. **Orders**: Data about customer orders including order ID, customer ID, order date, product ID, quantity, and price.
# 3. **Customers**: Data about customers including customer ID, name, email, address, and phone number.
# 4. **Products**: Data about products including product ID, name, category, price, and inventory.
# 5. **Shipping**: Data about shipping details including order ID, shipping address, shipping date, and tracking number.

# %% [markdown]
# ### Extraction Overview:

# %% [markdown]
# Data sources list:
#
# 1. Orders data - XML file
# 2. Customers data - XLS file
# 3. Products data - DataBase [SQL SERVER]
# 4. Shipping data - JSON file

# %% [markdown]
# ### Extraction Phase:

# %% [markdown]
# 1. Creating a new folder for project in Repository Manager.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Created folder with name. After creating, by use of the source qualifier we can start to extract data.
# ![image.png](attachment:image.png)

# %% [markdown]
# **Extraction process for Orders data:** <br>
# Order data was in XML format in Local Storage.

# %% [markdown]
# Local Storage location "C:\Informatic Projects\Datas"<br>
# File name : orders_xml.xml <br>
# **Steps:**
# 1. Navigating to the Informatica Designer and refreshing my folder list.
# ![image.png](attachment:image.png)
# 2. Open the source qualifier for the created folder.
# ![image-2.png](attachment:image-2.png)
# 3.
# ![image-3.png](attachment:image-3.png)
# 4. As next need to follow the on screen instruction to proceed futher with XML file.
# ![image-4.png](attachment:image-4.png)
# ![image-5.png](attachment:image-5.png)
# 5. XML file was successfully imported.
# ![image-6.png](attachment:image-6.png)

# %% [markdown]
# **Extraction process for customers data:** <br>
# customer data was in local as CSV file.<br>
# **Steps:**
# ![image.png](attachment:image.png)
# 1. Hovering on nav menu for source tab and click on "Import from file and choose the xls file.
# 2. Click on open button and flow the on screen prompt.
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# 3. Once you done successfull import it looks like below.
# ![image-4.png](attachment:image-4.png)
# 4. After completing of each process and steps in informatica powercenter click <code>ctrl + s</code> to save the progress.
# ![image-5.png](attachment:image-5.png)

# %% [markdown]
# **Extraction process for products data:** <br>
# product data was in SQL Server as Database Table.<br>
# **Steps:**
# ![image.png](attachment:image.png)
# 1. The above image has the sample data of the products.
# ![image-2.png](attachment:image-2.png)
# 2. From Designer importing from the database option.<br>
# ![image-3.png](attachment:image-3.png)
# 3. Following the onscreen prompt.<br>
# ![image-4.png](attachment:image-4.png)
# 4. Above, created the ODBC connection and imported the required data from the SQL Server.<br>
# ![image-5.png](attachment:image-5.png)
# 5. Successfully imported.

# %% [markdown]
# **Extraction process for shipping data:** <br>
# shipping data was in Local storage as JSON file.<br>
# **Steps:**
# 1. Informatica does not support JSON formatted file as of now. So we are using the ZappySys JSON Driver to import the JSON file.
# ![image.png](attachment:image.png)
# Installation and setup link:https://zappysys.com/products/odbc-powerpack/download/ and https://zappysys.com/onlinehelp/odbc-powerpack/index.htm#page=getting-started.htm.
# 2. Once installation and setup is completed successfully we can use relational ODBC to import the JSON file.
# ![image-2.png](attachment:image-2.png)
# 3. Click to connect.
#     **Note**: During the setup only you can able to configure the json file.
# 4. After import [need to follow some onscreen prompt instruction]
# ![image-3.png](attachment:image-3.png)
