# %%
print("Hello!, World")

# %%
import pandas as pd

# %%
df = pd.read_csv('cars.csv')
df
# Out:
#              Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
df = pd.read_csv('cars.csv', usecols=['vs','am'])
df
# Out:
#     vs  am
# 0    0   1
# 1    0   1
# 2    1   1
# 3    1   0
# 4    0   0
# 5    1   0
# 6    0   0
# 7    1   0
# 8    1   0
# 9    1   0
# 10   1   0
# 11   0   0
# 12   0   0
# 13   0   0
# 14   0   0
# 15   0   0
# 16   0   0
# 17   1   1
# 18   1   1
# 19   1   1
# 20   1   0
# 21   0   0
# 22   0   0
# 23   0   0
# 24   0   0
# 25   1   1
# 26   0   1
# 27   1   1
# 28   0   1
# 29   0   1
# 30   0   1
# 31   1   1

# %%
df_xl = pd.read_excel('pokemon_data.xlsx')
df_xl
# Out:
#      s.no                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0       1              Bulbasaur    Grass  Poison  45      49       49
# 1       2                Ivysaur    Grass  Poison  60      62       63
# 2       3               Venusaur    Grass  Poison  80      82       83
# 3       3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4       4             Charmander     Fire     NaN  39      52       43
# ..    ...                    ...      ...     ...  ..     ...      ...
# 795   719                Diancie     Rock   Fairy  50     100      150
# 796   719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797   720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798   720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799   721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df_xl = pd.read_excel('pokemon_data.xlsx',sheet_name=1)
df_xl
# Out:
#       hi        bye
# 0  mouli  mouli_pro

# %%
df_demo = pd.read_csv('class.csv')
df_demo
# Out:
#    Batch    Name  Marks_SQL  Marks_ETL
# 0      1  Pritam          8          7
# 1      2   Mouli          7          9
# 2      3   Salma         10         10

# %%
print(df_demo['Batch'].astype(str) + " " + df_demo['Name'].astype(str))
# Out:
# 0    1 Pritam
# 1     2 Mouli
# 2     3 Salma
# dtype: object

# %%
df11 = df_demo['Batch']
df22 = df_demo['Name']
df.join(df11,df22)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 3
#       1 df11 = df_demo['Batch']
#       2 df22 = df_demo['Name']
# ----> 3 df.join(df11,df22)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:9979, in DataFrame.join(self, other, on, how, lsuffix, rsuffix, sort, validate)
#    9816 def join(
#    9817     self,
#    9818     other: DataFrame | Series | list[DataFrame | Series],
#    (...)
#    9824     validate: str | None = None,
#    9825 ) -> DataFrame:
#    9826     """
#    9827     Join columns of another DataFrame.
#    9828
#    (...)
#    9977     5  K1  A5   B1
#    9978     """
# -> 9979     return self._join_compat(
#    9980         other,
#    9981         on=on,
#    9982         how=how,
#    9983         lsuffix=lsuffix,
#    9984         rsuffix=rsuffix,
#    9985         sort=sort,
# ...

# %%
df_demo_batch = pd.read_csv('class.csv', usecols = ['Batch'])
df_demo_name = pd.read_csv('class.csv', usecols = ['Name'])
df_demo_sql = pd.read_csv('class.csv', usecols = ['Marks_SQL'])
df_demo_etl = pd.read_csv('class.csv', usecols = ['Marks_ETL'])

df_demo = pd.concat([df_demo_batch, df_demo_name, df_demo_sql, df_demo_etl],axis=1)
df_demo['Total_Marks'] = df_demo['Marks_SQL'] + df_demo['Marks_ETL']
df_add_col = df_demo.insert(0,"Additional",[1,2,3])
df_demo
print(df_demo)
# Out:
#    Additional  Batch    Name  Marks_SQL  Marks_ETL  Total_Marks
# 0           1      1  Pritam          8          7           15
# 1           2      2   Mouli          7          9           16
# 2           3      3   Salma         10         10           20

# %%
print(df_demo_batch.join(df_demo_name))
# Out:
#    Batch    Name
# 0      1  Pritam
# 1      2   Mouli
# 2      3   Salma

# %%
print(pd.read_csv('class.csv', usecols = ['Batch']))
# Out:
#    Batch
# 0      1
# 1      2
# 2      3
